# %%
import pandas as pd
import numpy as np

df = pd.DataFrame([[1,2,3],
                [4,5,6],
                [7,8,9]])

df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
print(df.shape)
print(df.index)
# Out:
# (3, 3)
# RangeIndex(start=0, stop=3, step=1)

# %%
df2 = pd.DataFrame([[1,32,34], [1,32,34], [1,32,34], [1,32,34]], index=[1,2,4,5], columns=["a","w",'e'])

df2
# Out:
#    a   w   e
# 1  1  32  34
# 2  1  32  34
# 4  1  32  34
# 5  1  32  34

# %%
wdf = pd.read_csv("weather_2012.csv")
wdf.head(5)
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
print(wdf.shape)
print(wdf.index)
# Out:
# (8784, 8)
# RangeIndex(start=0, stop=8784, step=1)

# %%
print(wdf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
# Date/Time             8784 non-null object
# Temp (C)              8784 non-null float64
# Dew Point Temp (C)    8784 non-null float64
# Rel Hum (%)           8784 non-null int64
# Wind Spd (km/h)       8784 non-null int64
# Visibility (km)       8784 non-null float64
# Stn Press (kPa)       8784 non-null float64
# Weather               8784 non-null object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB
# None

# %%
wdf['Temp (C)'].unique()
# Out:
# array([ -1.8,  -1.5,  -1.4,  -1.3,  -1. ,  -0.5,  -0.2,   0.2,   0.8,
#          1.8,   2.6,   3. ,   3.8,   3.1,   3.2,   4. ,   4.4,   5.3,
#          5.2,   4.6,   3.9,   3.7,   2.9,   2.3,   2. ,   1.9,   1.5,
#          2.2,   1.7,   1.1,   0. ,  -0.7,  -2.1,  -4.1,  -4.8,  -5.6,
#         -5.8,  -7. ,  -7.4,  -9. ,  -9.7, -10.5, -11.3, -12.6, -12.9,
#        -13.3, -14. , -14.8, -15. , -15.3, -14.9, -15.1, -15.8, -16.3,
#        -16.9, -17.3, -17. , -17.1, -17.5, -17.9, -18.1, -18.5, -18.6,
#        -18.2, -17.8, -16.8, -15.2, -14.2, -13.7, -12.4, -10.2,  -9.4,
#         -8.9,  -8.4,  -7.8,  -7.6,  -9.5,  -9.6,  -8.8,  -7.5,  -5.4,
#         -5. ,  -8.2,  -7.1,  -6.1,  -6.6,  -6. ,  -4.7,  -4.4,  -5.1,
#         -4.3,  -6.7,  -9.2,  -9.8,  -9.9, -10. , -10.6, -11.8, -12. ,
#        -14.4, -12.3, -12.5, -11.7, -11.9, -11.2, -11.5, -11.6,  -9.3,
#         -8.7,  -8.5,  -8.1,  -6.9,  -6.4,  -5.7,  -5.5,  -3.7,  -3.6,
# ...

# %%
wdf['Temp (C)'].nunique() #number of unique values in a column
# Out:
# 533

# %%
wdf['Temp (C)'].value_counts()
# Out:
#  16.6    65
#  1.1     58
#  0.8     47
#  1.5     45
#  19.3    44
#  21.1    43
#  2.6     43
#  0.4     41
#  1.3     40
#  14.6    39
#  1.8     38
#  8.4     38
#  1.0     38
#  20.4    37
#  13.1    37
# -4.3     37
#  14.2    36
#  0.6     36
#  21.8    36
#  0.7     36
#  23.2    36
#  3.0     36
#  3.7     35
#  12.8    35
#  19.6    35
#  22.2    35
#  1.2     35
#  18.2    35
#  1.9     35
#  15.4    34
#          ..
# -20.6     1
#  30.0     1
# -20.3     1
# -17.6     1
# -23.3     1
# -19.6     1
# -18.2     1
# -21.0     1
# -19.5     1
#  31.8     1
# -19.3     1
#  32.9     1
# -21.4     1
#  32.8     1
# -21.2     1
#  32.4     1
# -17.0     1
# -23.2     1
#  30.3     1
#  32.3     1
# -19.0     1
# -20.0     1
# -19.9     1
# -22.8     1
#  31.4     1
# -19.1     1
# -21.3     1
#  32.7     1
#  32.6     1
# -17.7     1
# Name: Temp (C), Length: 533, dtype: int64

# %%
wdf['Temp (C)'].value_counts()[16.6]
# Out:
# 65

# %%
wdf.head(25)
# Out:
#               Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0   2012-01-01 00:00:00      -1.8                -3.9           86
# 1   2012-01-01 01:00:00      -1.8                -3.7           87
# 2   2012-01-01 02:00:00      -1.8                -3.4           89
# 3   2012-01-01 03:00:00      -1.5                -3.2           88
# 4   2012-01-01 04:00:00      -1.5                -3.3           88
# 5   2012-01-01 05:00:00      -1.4                -3.3           87
# 6   2012-01-01 06:00:00      -1.5                -3.1           89
# 7   2012-01-01 07:00:00      -1.4                -3.6           85
# 8   2012-01-01 08:00:00      -1.4                -3.6           85
# 9   2012-01-01 09:00:00      -1.3                -3.1           88
# 10  2012-01-01 10:00:00      -1.0                -2.3           91
# 11  2012-01-01 11:00:00      -0.5                -2.1           89
# 12  2012-01-01 12:00:00      -0.2                -2.0           88
# ...

# %%
wdf[:25]
# Out:
#               Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0   2012-01-01 00:00:00      -1.8                -3.9           86
# 1   2012-01-01 01:00:00      -1.8                -3.7           87
# 2   2012-01-01 02:00:00      -1.8                -3.4           89
# 3   2012-01-01 03:00:00      -1.5                -3.2           88
# 4   2012-01-01 04:00:00      -1.5                -3.3           88
# 5   2012-01-01 05:00:00      -1.4                -3.3           87
# 6   2012-01-01 06:00:00      -1.5                -3.1           89
# 7   2012-01-01 07:00:00      -1.4                -3.6           85
# 8   2012-01-01 08:00:00      -1.4                -3.6           85
# 9   2012-01-01 09:00:00      -1.3                -3.1           88
# 10  2012-01-01 10:00:00      -1.0                -2.3           91
# 11  2012-01-01 11:00:00      -0.5                -2.1           89
# 12  2012-01-01 12:00:00      -0.2                -2.0           88
# ...

# %%
wdf[:6:2][['Rel Hum (%)', 'Visibility (km)']]
# Out:
#    Rel Hum (%)  Visibility (km)
# 0           86              8.0
# 2           89              4.0
# 4           88              4.8

# %%
# Using loc
# NOTE: slice is `:5:2`, not 6 !
wdf.loc[:5:2, ['Rel Hum (%)', 'Visibility (km)']]
# Out:
#    Rel Hum (%)  Visibility (km)
# 0           86              8.0
# 2           89              4.0
# 4           88              4.8

# %%
# Using iloc
wdf.iloc[:6:2, [3,5]]
# Out:
#    Rel Hum (%)  Visibility (km)
# 0           86              8.0
# 2           89              4.0
# 4           88              4.8

# %%
# Basically, we want a way to "filter out" records that don't have the word "snow" (case insensitive) in the last column

snowed_filter = wdf['Weather'].str.lower().str.contains('snow')
wdf[snowed_filter]
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 41    2012-01-02 17:00:00      -2.1                -9.5           57
# 44    2012-01-02 20:00:00      -5.6               -13.4           54
# 45    2012-01-02 21:00:00      -5.8               -12.8           58
# 47    2012-01-02 23:00:00      -7.4               -14.1           59
# 48    2012-01-03 00:00:00      -9.0               -16.0           57
# 50    2012-01-03 02:00:00     -10.5               -15.8           65
# 51    2012-01-03 03:00:00     -11.3               -18.7           54
# 53    2012-01-03 05:00:00     -12.9               -19.1           60
# 54    2012-01-03 06:00:00     -13.3               -19.3           61
# 55    2012-01-03 07:00:00     -14.0               -19.5           63
# 84    2012-01-04 12:00:00     -13.7               -21.7           51
# 86    2012-01-04 14:00:00     -11.3               -19.0           53
# 87    2012-01-04 15:00:00     -10.2               -16.3           61
# ...

# %%
df = wdf[(wdf['Wind Spd (km/h)'] > 24) & (wdf['Visibility (km)']> 25)]
df.head()
# Out:
#                Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 109  2012-01-05 13:00:00      -4.4                -9.7           66
# 111  2012-01-05 15:00:00      -4.3               -12.0           55
# 350  2012-01-15 14:00:00     -16.0               -23.4           53
# 422  2012-01-18 14:00:00     -10.3               -17.6           55
# 423  2012-01-18 15:00:00     -10.4               -18.0           54
#
#      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)       Weather
# 109               26             48.3           100.40  Mainly Clear
# 111               26             48.3           100.52  Mainly Clear
# 350               26             48.3           102.66  Mainly Clear
# 422               28             48.3           101.19  Mainly Clear
# 423               30             48.3           101.32  Mainly Clear

# %%
wdf2 = pd.read_csv('weather_2012.csv', parse_dates=True, index_col='Date/Time')
wdf2.head()
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather
# Date/Time
# 2012-01-01 00:00:00                   Fog
# ...

# %%
wdf2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8784 entries, 2012-01-01 00:00:00 to 2012-12-31 23:00:00
# Data columns (total 7 columns):
# Temp (C)              8784 non-null float64
# Dew Point Temp (C)    8784 non-null float64
# Rel Hum (%)           8784 non-null int64
# Wind Spd (km/h)       8784 non-null int64
# Visibility (km)       8784 non-null float64
# Stn Press (kPa)       8784 non-null float64
# Weather               8784 non-null object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 549.0+ KB

# %%
 wdf2.loc['2012-01-06', 'Stn Press (kPa)'].head(5)
# Out:
# Date/Time
# 2012-01-06 00:00:00    100.81
# 2012-01-06 01:00:00    100.81
# 2012-01-06 02:00:00    100.84
# 2012-01-06 03:00:00    100.76
# 2012-01-06 04:00:00    100.70
# Name: Stn Press (kPa), dtype: float64

# %%
#when snow was recorded
snow_filter = wdf2['Weather'].str.lower().str.contains('snow')
wdf2[snow_filter].head()
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-02 17:00:00      -2.1                -9.5           57
# 2012-01-02 20:00:00      -5.6               -13.4           54
# 2012-01-02 21:00:00      -5.8               -12.8           58
# 2012-01-02 23:00:00      -7.4               -14.1           59
# 2012-01-03 00:00:00      -9.0               -16.0           57
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-02 17:00:00               22             25.0            99.66
# 2012-01-02 20:00:00               24             25.0           100.07
# 2012-01-02 21:00:00               26             25.0           100.15
# 2012-01-02 23:00:00               17             19.3           100.27
# 2012-01-03 00:00:00               28             25.0           100.35
#
#                           Weather
# Date/Time
# 2012-01-02 17:00:00  Snow Showers
# 2012-01-02 20:00:00  Snow Showers
# ...

# %%
#wind speed was above 24 and visibility was 25
wind_visibility_filter = (wdf2['Wind Spd (km/h)'] > 24) & (wdf2['Visibility (km)'] == 25)
wdf2[wind_visibility_filter]
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 23:00:00       5.3                 2.0           79
# 2012-01-02 00:00:00       5.2                 1.5           77
# 2012-01-02 01:00:00       4.6                 0.0           72
# 2012-01-02 02:00:00       3.9                -0.9           71
# 2012-01-02 03:00:00       3.7                -1.5           69
# 2012-01-02 04:00:00       2.9                -2.3           69
# 2012-01-02 05:00:00       2.6                -2.3           70
# 2012-01-02 06:00:00       2.3                -2.6           70
# 2012-01-02 07:00:00       2.0                -2.9           70
# 2012-01-02 18:00:00      -4.1               -11.4           57
# 2012-01-02 21:00:00      -5.8               -12.8           58
# 2012-01-03 00:00:00      -9.0               -16.0           57
# 2012-01-03 03:00:00     -11.3               -18.7           54
# 2012-01-08 00:00:00       0.6                -3.2           76
# ...

# %%
add_10 = wdf2["Wind Spd (km/h)"] + 100
print(add_10.head())
mult_2 = weather_df2['Visibility (km)'] * 2
print(mult_2.head())
temperature = weather_df2["Temp (C)"] + weather_df2["Dew Point Temp (C)"]
print(temperature.head())
# Out:
# Date/Time
# 2012-01-01 00:00:00    104
# 2012-01-01 01:00:00    104
# 2012-01-01 02:00:00    107
# 2012-01-01 03:00:00    106
# 2012-01-01 04:00:00    107
# Name: Wind Spd (km/h), dtype: int64
# Date/Time
# 2012-01-01 00:00:00    16.0
# 2012-01-01 01:00:00    16.0
# 2012-01-01 02:00:00     8.0
# 2012-01-01 03:00:00     8.0
# 2012-01-01 04:00:00     9.6
# Name: Visibility (km), dtype: float64
# Date/Time
# 2012-01-01 00:00:00   -5.7
# 2012-01-01 01:00:00   -5.5
# 2012-01-01 02:00:00   -5.2
# 2012-01-01 03:00:00   -4.7
# 2012-01-01 04:00:00   -4.8
# dtype: float64

# %%
wdf2['Visibility (km)'].describe()
# Out:
# count    8784.000000
# mean       27.664447
# std        12.622688
# min         0.200000
# 25%        24.100000
# 50%        25.000000
# 75%        25.000000
# max        48.300000
# Name: Visibility (km), dtype: float64

# %%
wdf2.describe(include='all')
# Out:
#            Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# count   8784.000000         8784.000000  8784.000000      8784.000000
# unique          NaN                 NaN          NaN              NaN
# top             NaN                 NaN          NaN              NaN
# freq            NaN                 NaN          NaN              NaN
# mean       8.798144            2.555294    67.431694        14.945469
# std       11.687883           10.883072    16.918881         8.688696
# min      -23.300000          -28.500000    18.000000         0.000000
# 25%        0.100000           -5.900000    56.000000         9.000000
# 50%        9.300000            3.300000    68.000000        13.000000
# 75%       18.800000           11.800000    81.000000        20.000000
# max       33.000000           24.400000   100.000000        83.000000
#
#         Visibility (km)  Stn Press (kPa)       Weather
# count       8784.000000      8784.000000          8784
# ...

# %%
wdf2['Weather'].describe()
# Out:
# count             8784
# unique              50
# top       Mainly Clear
# freq              2106
# Name: Weather, dtype: object

# %%
wdf2['Visibility (km)'].min()
# Out:
# 0.2

# %%
def minus2(x):
    return x-200

wdf2['Visibility (km)'].apply(minus2).head()
# Out:
# Date/Time
# 2012-01-01 00:00:00   -192.0
# 2012-01-01 01:00:00   -192.0
# 2012-01-01 02:00:00   -196.0
# 2012-01-01 03:00:00   -196.0
# 2012-01-01 04:00:00   -195.2
# Name: Visibility (km), dtype: float64

# %%
# Adding Columns
visibility_in_meter = wdf2["Visibility (km)"] * 1000  
wdf2["Visibility (m)"] = visibility_in_meter

wdf2.head()
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather  Visibility (m)
# Date/Time
# 2012-01-01 00:00:00                   Fog          8000.0
# ...

# %%
# Renaming Columns
wdf2.rename(columns={'Visibility (m)': 'Visibility (meters)'}, inplace=True)
wdf2.head()
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather  Visibility (meters)
# Date/Time
# ...

# %%
wdf2.drop(columns=['Visibility (meters)'], inplace=True)
wdf2.head()
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather
# Date/Time
# 2012-01-01 00:00:00                   Fog
# ...

# %%
#SORTING

sorted_by_temp = wdf2.sort_values('Temp (C)', ascending=True)  # can be inplace as well
sorted_by_temp.head()
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-15 08:00:00     -23.3               -28.5           62
# 2012-01-15 06:00:00     -23.2               -28.5           62
# 2012-01-15 07:00:00     -22.8               -28.0           62
# 2012-01-15 09:00:00     -22.2               -27.8           60
# 2012-01-15 02:00:00     -21.4               -26.6           63
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-15 08:00:00                7             24.1           102.45
# 2012-01-15 06:00:00                7             25.0           102.28
# 2012-01-15 07:00:00                9             25.0           102.37
# 2012-01-15 09:00:00                9             48.3           102.57
# 2012-01-15 02:00:00                9             25.0           101.99
#
#                            Weather
# Date/Time
# 2012-01-15 08:00:00          Clear
# 2012-01-15 06:00:00  Mostly Cloudy
# ...

# %%
#top 10 hottest values and their counts

hottest = wdf['Temp (C)'].sort_values(ascending=False).value_counts(sort=False)
hottest.iloc[:10]
# Out:
# 33.0     2
# 32.0     1
# 28.0    11
# 24.0    17
# 22.0    24
# 20.0    34
# 16.0    29
# 14.0    25
# 13.0    25
# 12.0    26
# Name: Temp (C), dtype: int64

# %%
#mean temperature recorded by month
#Solution 1
mean_temperatures = {}

for month in range(1, 13):
    mean_temperatures[month] = weather_df2.loc[weather_df2.index.month == month, 'Temp (C)'].mean()

pd.Series(mean_temperatures)
# Out:
# {1: -7.371505376344083,
#  2: -4.2250000000000005,
#  3: 3.1212365591397853,
#  4: 7.0093055555555575,
#  5: 16.2377688172043,
#  6: 20.134027777777785,
#  7: 22.790053763440845,
#  8: 22.279301075268787,
#  9: 16.484444444444463,
#  10: 10.954973118279568,
#  11: 0.9313888888888887,
#  12: -3.3063172043010765}

# %%
#PIVOT TABLES
#Solution2

mean_temp = wdf2.pivot_table(values=['Temp (C)'],
                             index=wdf2.index.month,
                             aggfunc='mean') #np.mean
mean_temp``
# Out:
#             Temp (C)
# Date/Time
# 1          -7.371505
# 2          -4.225000
# 3           3.121237
# 4           7.009306
# 5          16.237769
# 6          20.134028
# 7          22.790054
# 8          22.279301
# 9          16.484444
# 10         10.954973
# 11          0.931389
# 12         -3.306317

# %%
#GroupBy
wdf2.groupby(wdf2.index.month).agg(np.mean).reset_index()
# Out:
#     Date/Time   Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# 0           1  -7.371505          -12.294758    68.383065        18.108871
# 1           2  -4.225000           -9.221695    68.956897        14.837644
# 2           3   3.121237           -3.488575    64.862903        14.514785
# 3           4   7.009306           -1.934583    56.150000        17.369444
# 4           5  16.237769            8.080780    61.760753        12.846774
# 5           6  20.134028           11.738056    60.643056        14.681944
# 6           7  22.790054           14.595430    62.017473        11.887097
# 7           8  22.279301           15.644758    67.943548        13.931452
# 8           9  16.484444           10.757917    71.165278        14.108333
# 9          10  10.954973            6.533468    75.731183        15.475806
# 10         11   0.931389           -4.179306    69.984722        13.973611
# ...
